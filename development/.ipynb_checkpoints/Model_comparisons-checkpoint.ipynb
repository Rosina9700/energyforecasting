# %%
import warnings
import itertools
import pandas as pd
import plotting as mp
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from data_wrangling import Results_data
from collections import OrderedDict
from baseline_models import Baseline_previous, Baseline_average
plt.style.use('fivethirtyeight')

# %%
def get_results(project_name, frequency):
    filename = '{}_{}_fbeta.csv'.format(project_name, frequency)
    print filename
    df = Results_data(filename).get_data().df
    cross_val_scores = {}
    cross_val_scores['b1'] = df.iloc[0]['baseline_previous']
    cross_val_scores['b2'] = df.iloc[0]['baseline_averages']
    cross_val_scores['sarima'] = df.iloc[0]['sarima_x']
    cross_val_scores['sarimaX_f'] = df.iloc[2]['sarima_x']
    filename = '{}_{}_vbeta.csv'.format(project_name, frequency)
    df = Results_data(filename).get_data().df
    cross_val_scores['sarimaX_v'] = df.iloc[2]['sarima_x']
    results = OrderedDict(sorted(cross_val_scores.items(), key=lambda t: t[0]))
    return df, results

# %%
def get_test_results(project_name, frequency):
    filename = '{}_{}_fbeta.csv'.format(project_name, frequency)
    print filename
    df = Results_data(filename).get_data().df
    test_scores = {}
    test_scores['b1'] = df.iloc[1]['baseline_previous']
    test_scores['b2'] = df.iloc[1]['baseline_averages']
    test_scores['sarima'] = df.iloc[1]['sarima_x']
    test_scores['sarimaX_f'] = df.iloc[3]['sarima_x']
    filename = '{}_{}_vbeta.csv'.format(project_name, frequency)
    df = Results_data(filename).get_data().df
    test_scores['sarimaX_v'] = df.iloc[3]['sarima_x']
    results = OrderedDict(sorted(test_scores.items(), key=lambda t: t[0]))
    return df, results

# %% [markdown]
# ## Daily

# %%
df, res = get_results('project_6d8c','daily')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_6d8c_daily_fbeta.csv

# %%
df, res = get_test_results('project_6d8c','daily')
plot = res
plt.bar(range(len(plot)),plot.values(), color='r', align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_6d8c_daily_fbeta.csv

# %%
df, res = get_results('project_34a6','daily')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_34a6_daily_fbeta.csv

# %%
df, res = get_test_results('project_34a6','daily')
plot = res
plt.bar(range(len(plot)),plot.values(), color='r',align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_34a6_daily_fbeta.csv

# %%
# Too short to be reliable
df, res = get_results('project_1074','daily')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_1074_daily_fbeta.csv

# %%
df, res = get_results('project_5526','daily')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_5526_daily_fbeta.csv

# %%
df, res = get_test_results('project_5526','daily')
plot = res
plt.bar(range(len(plot)),plot.values(), color='r',align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_5526_daily_fbeta.csv

# %%
df, res = get_results('project_a1e0','daily')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_a1e0_daily_fbeta.csv

# %%
df, res = get_test_results('project_a1e0','daily')
plot = res
plt.bar(range(len(plot)),plot.values(),color='r', align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_a1e0_daily_fbeta.csv

# %%
df, res = get_results('project_e871','daily')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_e871_daily_fbeta.csv

# %%
df, res = get_test_results('project_e871','daily')
plot = res
plt.bar(range(len(plot)),plot.values(), color='r', align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# project_e871_daily_fbeta.csv
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-44-6aa1480d9c8b> in <module>()
# ----> 1 df, res = get_test_results('project_e871','daily')
#       2 plot = res
#       3 plt.bar(range(len(plot)),plot.values(), color='r', align='center')
#       4 plt.xticks(range(len(plot)), plot.keys())
#       5
#
# <ipython-input-21-eff127b6c19e> in get_test_results(project_name, frequency)
#       2     filename = '{}_{}_fbeta.csv'.format(project_name, frequency)
#       3     print filename
# ----> 4     df = Results_data(filename).get_data().df
#       5     test_scores = {}
#       6     test_scores['b1'] = df.iloc[1]['baseline_previous']
#
# /home/rosina/git_hub/dsi-capstone/development/data_wrangling.pyc in get_data(self)
#      27     def get_data(self):
#      28         filelocation = 'output_{}_fbeta.csv'.format(self.project_name)
# ---> 29         df1 = pd.read_csv(filelocation,sep=';')
#      30         df1['order'] = df1['sarimax_params'].apply(self.get_order)
#      31         df1['seasonal_order'] = df1['sarimax_params'].apply(self.get_seasonal_order)
#
# /home/rosina/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /home/rosina/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /home/rosina/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     760             self.options['has_index_names'] = kwds['has_index_names']
#     761
# --> 762         self._make_engine(self.engine)
#     763
#     764     def close(self):
#
# /home/rosina/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     964     def _make_engine(self, engine='c'):
#     965         if engine == 'c':
# --> 966             self._engine = CParserWrapper(self.f, **self.options)
#     967         else:
#     968             if engine == 'python':
#
# /home/rosina/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1580         kwds['allow_leading_cols'] = self.index_col is not False
#    1581
# -> 1582         self._reader = parsers.TextReader(src, **kwds)
#    1583
#    1584         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# IOError: File output_project_e871_daily_fbeta.csv_fbeta.csv does not exist

# %% [markdown]
# ## Hourly

# %%
def get_results(project_name, frequency):
    filename = 'results/output_{}_{}_fbeta.csv'.format(project_name, frequency)
    print filename
    df = Results_data(filename).get_data().df
    cross_val_scores = {}
    cross_val_scores['b1'] = df.iloc[0]['baseline_previous']
    cross_val_scores['b2'] = df.iloc[0]['baseline_averages']
    cross_val_scores['sarima'] = df.iloc[0]['sarimax']
    cross_val_scores['sarimaX_f'] = df.iloc[2]['sarimax']
#     filename = '{}_{}_vbeta.csv'.format(project_name, frequency)
#     df = Results_data(filename).get_data().df
#     cross_val_scores['sarimaX_v'] = df.iloc[2]['sarimax']
    results = OrderedDict(sorted(cross_val_scores.items(), key=lambda t: t[0]))
    return df, results

# %%
df, res = get_results('project_6d8c','hourly')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# results/output_project_6d8c_hourly_fbeta.csv

# %%
df, res = get_results('project_34a6','hourly')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# results/output_project_34a6_hourly_fbeta.csv

# %%
df, res = get_results('project_1074','hourly')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# results/output_project_1074_hourly_fbeta.csv

# %%
df, res = get_results('project_5526','hourly')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# results/output_project_5526_hourly_fbeta.csv

# %%
df, res = get_results('project_a1e0','hourly')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# results/output_project_a1e0_hourly_fbeta.csv

# %%
df, res = get_results('project_e871','hourly')
plot = res
plt.bar(range(len(plot)),plot.values(), align='center')
plt.xticks(range(len(plot)), plot.keys())

plt.show()
# Out:
# results/output_project_e871_hourly_fbeta.csv
